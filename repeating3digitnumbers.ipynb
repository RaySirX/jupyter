# %%
import string, random, re

# %%
s = ''.join(random.choice(string.digits) for _ in range(1000))

# %%
print(s)
# Out:
# ...

# %%
frq = { str(a).zfill(3) : len(re.findall(str(a).zfill(3),s)) for a in range(1000) }

# %%
print(frq)
# Out:
# {'000': 2, '001': 2, '002': 2, '003': 0, '004': 2, '005': 1, '006': 1, '007': 2, '008': 2, '009': 1, '010': 0, '011': 0, '012': 1, '013': 0, '014': 0, '015': 0, '016': 1, '017': 1, '018': 2, '019': 2, '020': 2, '021': 2, '022': 2, '023': 0, '024': 0, '025': 0, '026': 2, '027': 1, '028': 0, '029': 2, '030': 0, '031': 0, '032': 0, '033': 2, '034': 1, '035': 2, '036': 1, '037': 0, '038': 3, '039': 3, '040': 4, '041': 0, '042': 2, '043': 1, '044': 0, '045': 1, '046': 1, '047': 3, '048': 2, '049': 0, '050': 1, '051': 1, '052': 1, '053': 0, '054': 0, '055': 0, '056': 1, '057': 0, '058': 2, '059': 1, '060': 1, '061': 0, '062': 0, '063': 0, '064': 2, '065': 1, '066': 0, '067': 0, '068': 0, '069': 1, '070': 1, '071': 1, '072': 4, '073': 0, '074': 0, '075': 1, '076': 1, '077': 1, '078': 1, '079': 0, '080': 0, '081': 1, '082': 1, '083': 1, '084': 2, '085': 1, '086': 1, '087': 1, '088': 0, '089': 0, '090': 1, '091': 4, '092': 0, '093': 1, '094': 1, '095': 0, '096': 1, '097': 0, '098': 0, '099': 
# ...
